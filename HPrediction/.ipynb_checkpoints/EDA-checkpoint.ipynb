# %% [markdown]
# <h1>Exploratory data analyis</h1>

# %%
#import libraries
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline 
import seaborn as sns

# %%
df=pd.read_csv("project_files/house_listingskenya.csv")

# %% [markdown]
# <h2>Basic info</h2>

# %%
df.shape
# Out:
# (16117, 17)

# %%
df_cat = df.select_dtypes(include = "object")
categorical_features = df.loc[:, ~df.columns.isin(['listdate', 'locality'])].dtypes[df.dtypes == 'object'].index
df_rental=df[df.category == 'For Rent']

# %%
df_rental.head(15)
# Out:
#     id     price price_qualifier  bedrooms  bathrooms  toilets  furnished  \
# 0    1    5000.0       per month         3          0      NaN          0
# 6    7  200000.0       per month         5          5      5.0          0
# 7    8  100000.0       per month         3          3      3.0          0
# 9   10  120000.0       per month         3          3      3.0          0
# 10  11  180000.0       per month         2          2      2.0          1
# 11  12  210000.0       per month         4          4      4.0          0
# 12  13  270000.0             NaN         4          4      4.0          0
# 13  14  230000.0       per month         3          3      3.0          1
# 14  15  180000.0       per month         3          3      3.0          1
# 15  16  275000.0       per month         4          4      4.0          0
# 16  17  540000.0       per month         6          6      6.0          0
# 17  18  380000.0       per month         4          4      4.0          0
# 18  19  350000.0       per month         3          3      3.0          1
# 19  20  350000.0       per month         4          4      4.0          0
# 20  21  230000.0       per month         3          3      3.0          0
#
#     serviced  shared  parking  category       type         sub_type    state  \
# 0          0       0        0  For Rent  Apartment              NaN  Nairobi
# 6          0       0        0  For Rent      House        Townhouse  Nairobi
# 7          0       0        0  For Rent  Apartment              NaN  Nairobi
# 9          0       0        0  For Rent  Apartment              NaN  Nairobi
# 10         0       0        0  For Rent  Apartment              NaN  Nairobi
# 11         0       0        0  For Rent      House              NaN  Nairobi
# 12         0       0        0  For Rent      House        Townhouse  Nairobi
# 13         0       0        0  For Rent  Apartment              NaN  Nairobi
# 14         0       0        0  For Rent  Apartment              NaN  Nairobi
# 15         0       0        0  For Rent      House        Townhouse  Nairobi
# 16         0       0        0  For Rent      House              NaN  Nairobi
# 17         0       0        0  For Rent      House  Detached Duplex  Nairobi
# 18         0       0        0  For Rent      House              NaN  Nairobi
# 19         0       0        0  For Rent      House              NaN  Nairobi
# 20         0       0        0  For Rent  Apartment              NaN  Nairobi
#
#            locality    sub_locality             listdate
# 0          Embakasi          Tassia  2020-07-18 00:00:00
# 6   Nairobi Central             NaN  2020-07-18 00:00:00
# 7         Parklands             NaN  2020-07-18 00:00:00
# 9         Lavington             NaN  2020-07-18 00:00:00
# 10        Westlands             NaN  2020-07-18 00:00:00
# 11         Muthaiga  Muthaiga North  2020-07-18 00:00:00
# 12        Lavington             NaN  2020-07-18 00:00:00
# 13       Kileleshwa             NaN  2020-07-18 00:00:00
# 14        Westlands             NaN  2020-07-18 00:00:00
# 15         Kitisuru             NaN  2020-07-18 00:00:00
# 16        Westlands             NaN  2020-07-18 00:00:00
# 17  Nairobi Central             NaN  2020-07-18 00:00:00
# 18         Muthaiga    Old Muthaiga  2020-07-18 00:00:00
# 19        Westlands           Runda  2020-07-18 00:00:00
# 20        Westlands             NaN  2020-07-18 00:00:00

# %%
df.dtypes
# Out:
# id                   int64
# price              float64
# price_qualifier     object
# bedrooms             int64
# bathrooms            int64
# toilets            float64
# furnished            int64
# serviced             int64
# shared               int64
# parking              int64
# category            object
# type                object
# sub_type            object
# state               object
# locality            object
# sub_locality        object
# listdate            object
# dtype: object

# %%
df.isnull().sum()
# Out:
# id                     0
# price                  3
# price_qualifier     8870
# bedrooms               0
# bathrooms              0
# toilets            10028
# furnished              0
# serviced               0
# shared                 0
# parking                0
# category               0
# type                   0
# sub_type            9817
# state                  0
# locality               6
# sub_locality       15071
# listdate               0
# dtype: int64

# %%
#comment
